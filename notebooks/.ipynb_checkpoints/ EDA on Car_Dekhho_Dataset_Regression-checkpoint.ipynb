# %%
# importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
car = pd.read_csv("C:\\Users\\LENOVO\\Downloads\\car-details-v3.csv")

# %%
car.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
car.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %% [markdown]
# # EDA ON CAR DATA SET

# %%
# convert mileage (kmpl) object type to flot type
car['mileage'] = car['mileage'].apply(lambda x: float(x.split()[0]) if type(x)==str else np.nan)
car['mileage'] = car['mileage'].astype("float")

# %%
# remove (cc) from engine 
car['engine'] = car['engine'].apply(lambda x: x.replace("CC","") if type(x)==str else np.nan)

# %%
# remove bph from max_power convet object type to flot type
car['max_power'] = car['max_power'].apply(lambda x : x.split()[0] if type(x)==str else np.nan )

# %%
car[['mileage','engine','max_power']]
# Out:
#       mileage engine max_power
# 0       23.40  1248         74
# 1       21.14  1498     103.52
# 2       17.70  1497         78
# 3       23.00  1396         90
# 4       16.10  1298       88.2
# ...       ...    ...       ...
# 8123    18.50  1197      82.85
# 8124    16.80  1493        110
# 8125    19.30  1248       73.9
# 8126    23.57  1396         70
# 8127    23.57  1396         70
#
# [8128 rows x 3 columns]

# %%
# convert seats flot to categorical
print("Before converting dtype: " + str(car.seats.dtype))
car.seats = car.seats.astype('category')
print("After converting dtype: " + str(car.seats.dtype))
# Out:
# Before converting dtype: float64
# After converting dtype: category

# %%
car[car["mileage"].isnull() & car["engine"].isnull() & car["seats"].isnull()]
# Out:
#                                       name  year  selling_price  km_driven  \
# 13                    Maruti Swift 1.3 VXi  2007         200000      80000
# 31                      Fiat Palio 1.2 ELX  2003          70000      50000
# 78                         Tata Indica DLS  2003          50000      70000
# 87             Maruti Swift VDI BSIV W ABS  2015         475000      78000
# 119                  Maruti Swift VDI BSIV  2010         300000     120000
# ...                                    ...   ...            ...        ...
# 7846                Toyota Qualis Fleet A3  2000         200000     100000
# 7996             Hyundai Santro LS zipPlus  2000         140000      50000
# 8009  Hyundai Santro Xing XS eRLX Euro III  2006         145000      80000
# 8068             Ford Figo Aspire Facelift  2017         580000     165000
# 8103                  Maruti Swift 1.3 VXi  2006         130000     100000
#
#         fuel seller_type transmission         owner  mileage engine max_power  \
# 13    Petrol  Individual       Manual  Second Owner      NaN    NaN       NaN
# 31    Petrol  Individual       Manual  Second Owner      NaN    NaN       NaN
# 78    Diesel  Individual       Manual   First Owner      NaN    NaN       NaN
# 87    Diesel      Dealer       Manual   First Owner      NaN    NaN       NaN
# 119   Diesel  Individual       Manual  Second Owner      NaN    NaN       NaN
# ...      ...         ...          ...           ...      ...    ...       ...
# 7846  Diesel  Individual       Manual   First Owner      NaN    NaN       NaN
# 7996  Petrol  Individual       Manual  Second Owner      NaN    NaN       NaN
# 8009  Petrol  Individual       Manual  Second Owner      NaN    NaN       NaN
# 8068  Diesel  Individual       Manual   First Owner      NaN    NaN       NaN
# 8103  Petrol  Individual       Manual  Second Owner      NaN    NaN       NaN
#
#      torque seats
# 13      NaN   NaN
# 31      NaN   NaN
# 78      NaN   NaN
# 87      NaN   NaN
# 119     NaN   NaN
# ...     ...   ...
# 7846    NaN   NaN
# 7996    NaN   NaN
# 8009    NaN   NaN
# 8068    NaN   NaN
# 8103    NaN   NaN
#
# [221 rows x 13 columns]

# %%
car.dropna(inplace=True)

# %%
car.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7906 non-null   object
#  1   year           7906 non-null   int64
#  2   selling_price  7906 non-null   int64
#  3   km_driven      7906 non-null   int64
#  4   fuel           7906 non-null   object
#  5   seller_type    7906 non-null   object
#  6   transmission   7906 non-null   object
#  7   owner          7906 non-null   object
#  8   mileage        7906 non-null   float64
#  9   engine         7906 non-null   object
#  10  max_power      7906 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7906 non-null   category
# dtypes: category(1), float64(1), int64(3), object(8)
# memory usage: 811.0+ KB

# %%
car["engine"] = car["engine"].astype(int)
car["max_power"] = car["max_power"].astype(float)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7906 non-null   object
#  1   year           7906 non-null   int64
#  2   selling_price  7906 non-null   int64
#  3   km_driven      7906 non-null   int64
#  4   fuel           7906 non-null   object
#  5   seller_type    7906 non-null   object
#  6   transmission   7906 non-null   object
#  7   owner          7906 non-null   object
#  8   mileage        7906 non-null   float64
#  9   engine         7906 non-null   int32
#  10  max_power      7906 non-null   float64
#  11  torque         7906 non-null   object
#  12  seats          7906 non-null   category
# dtypes: category(1), float64(2), int32(1), int64(3), object(6)
# memory usage: 780.2+ KB

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4), sharey=True)
fig.suptitle('Visuallization of categorical columns')

# Fuel_Type
sns.barplot(x = 'fuel', y = 'selling_price', data = car, ax = axes[0],palette="Blues_d")

# Seller_Type
sns.barplot(x = 'seller_type', y = 'selling_price', data = car, ax = axes[1],palette="Blues_d")

# Transmission
sns.barplot(x = 'transmission', y = 'selling_price', data = car, ax = axes[2],palette="Blues_d")
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='selling_price'>

# %%
data=pd.data(model.features_importance_, index=X.columns)
data.sort_values(ascending=False).plot(king='barh')
plt.show()

# %%
## plot heatmap for car data
sns.heatmap(car.isnull())
plt.show()

# %%
sns.heatmap(car.corr())
plt.show()

# %%
car['price_Diff']=car['km_driven']-car['selling_price']

# %%
f, axes=plt.subplots(2,2, figsize=(19,8))
sns.barplot(x='transmission',y='price_Diff',data=car,ax=axes[1,0])
sns.barplot(x='fuel',y='price_Diff',data=car,ax=axes[1,1])
sns.barplot(x='owner',y='price_Diff',data=car,ax=axes[0,1])
sns.barplot(x='seller_type',y='price_Diff',data=car,ax=axes[0,0])
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='price_Diff'>

# %%
car['year']=2019-car['year']

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='year',y='selling_price',ata=car)
# Out:
# <AxesSubplot:xlabel='year', ylabel='selling_price'>

# %%
car['fuel'].value_counts()
# Out:
# Diesel    4299
# Petrol    3520
# CNG         52
# LPG         35
# Name: fuel, dtype: int64

# %%
sns.countplot(x='fuel',data=car)
plt.show()

# %% [markdown]
# maximum car are using diesel

# %%
car['seller_type'].value_counts()
# Out:
# Individual          6563
# Dealer              1107
# Trustmark Dealer     236
# Name: seller_type, dtype: int64

# %%
sns.countplot(x='seller_type', data=car)   
plt.show()

# %% [markdown]
# there are maximum Individual seller type

# %%
car['transmission'].value_counts()
# Out:
# Manual       6865
# Automatic    1041
# Name: transmission, dtype: int64

# %%
sns.countplot(x='transmission',data=car)
plt.show()

# %% [markdown]
# there are more manul transmission type

# %%
car['owner'].value_counts()
# Out:
# First Owner             5215
# Second Owner            2016
# Third Owner              510
# Fourth & Above Owner     160
# Test Drive Car             5
# Name: owner, dtype: int64

# %%
sns.countplot(x='owner',data=car)
plt.show()

# %% [markdown]
# most of the owners are "first owners"

# %%
car.seats.value_counts()
# Out:
# 5.0     6254
# 7.0     1120
# 8.0      235
# 4.0      133
# 9.0       80
# 6.0       62
# 10.0      19
# 2.0        2
# 14.0       1
# Name: seats, dtype: int64

# %%
sns.countplot(x='seats',data=car)
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\pandas\io\formats\format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())

# %% [markdown]
# most of the customers prefer 5 seater cars

# %%
sns.pairplot(car, size = 2)
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
car.drop(['torque'],axis=1,inplace=True)

# %% [markdown]
# # saving to pickel

# %%
with open('EDA_CarDekho.pkl', 'wb') as f:
    pickle.dump(car, f)

# %%
EDA_File=pickle.load(open('EDA_CarDekho.pkl','rb'))

# %%
EDA_File
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI     5         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition     5         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi    13         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel     9         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII    12         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna     6         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX    12         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi    10         382000     120000  Diesel
# 8126               Tata Indigo CR4     6         290000      25000  Diesel
# 8127               Tata Indigo CR4     6         290000      25000  Diesel
#
#      seller_type transmission                 owner  mileage  engine  \
# 0     Individual       Manual           First Owner    23.40    1248
# 1     Individual       Manual          Second Owner    21.14    1498
# 2     Individual       Manual           Third Owner    17.70    1497
# 3     Individual       Manual           First Owner    23.00    1396
# 4     Individual       Manual           First Owner    16.10    1298
# ...          ...          ...                   ...      ...     ...
# 8123  Individual       Manual           First Owner    18.50    1197
# 8124  Individual       Manual  Fourth & Above Owner    16.80    1493
# 8125  Individual       Manual           First Owner    19.30    1248
# 8126  Individual       Manual           First Owner    23.57    1396
# 8127  Individual       Manual           First Owner    23.57    1396
#
#       max_power seats  price_Diff
# 0         74.00   5.0     -304500
# 1        103.52   5.0     -250000
# 2         78.00   5.0      -18000
# 3         90.00   5.0      -98000
# 4         88.20   5.0      -10000
# ...         ...   ...         ...
# 8123      82.85   5.0     -210000
# 8124     110.00   5.0      -16000
# 8125      73.90   5.0     -262000
# 8126      70.00   5.0     -265000
# 8127      70.00   5.0     -265000
#
# [7906 rows x 13 columns]

# %%
x =  EDAFile[['name','year','km_driven','fuel','seller_type','transmission', 'owner', 'mileage', 'engine', 'max_power','seats', 
              'price_Diff']]

# %%
y=EDA_File['selling_price']

# %%
x
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI     5         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition     5         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi    13         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel     9         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII    12         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna     6         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX    12         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi    10         382000     120000  Diesel
# 8126               Tata Indigo CR4     6         290000      25000  Diesel
# 8127               Tata Indigo CR4     6         290000      25000  Diesel
#
#      seller_type transmission                 owner  mileage  engine  \
# 0     Individual       Manual           First Owner    23.40    1248
# 1     Individual       Manual          Second Owner    21.14    1498
# 2     Individual       Manual           Third Owner    17.70    1497
# 3     Individual       Manual           First Owner    23.00    1396
# 4     Individual       Manual           First Owner    16.10    1298
# ...          ...          ...                   ...      ...     ...
# 8123  Individual       Manual           First Owner    18.50    1197
# 8124  Individual       Manual  Fourth & Above Owner    16.80    1493
# 8125  Individual       Manual           First Owner    19.30    1248
# 8126  Individual       Manual           First Owner    23.57    1396
# 8127  Individual       Manual           First Owner    23.57    1396
#
#       max_power seats  price_Diff
# 0         74.00   5.0     -304500
# 1        103.52   5.0     -250000
# 2         78.00   5.0      -18000
# 3         90.00   5.0      -98000
# 4         88.20   5.0      -10000
# ...         ...   ...         ...
# 8123      82.85   5.0     -210000
# 8124     110.00   5.0      -16000
# 8125      73.90   5.0     -262000
# 8126      70.00   5.0     -265000
# 8127      70.00   5.0     -265000
#
# [7906 rows x 13 columns]

# %%
y
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8123    320000
# 8124    135000
# 8125    382000
# 8126    290000
# 8127    290000
# Name: selling_price, Length: 7906, dtype: int64
